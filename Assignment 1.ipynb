# %% [markdown]
# # Assignment 1: CNN model

# %% [markdown]
# ### Tutorial CNN Implementation Script

# %% [markdown]
# Necessary dependencies & libraries

# %%
# %pip install numpy keras matplotlib pydot

# %%
# For PC
# %pip install tensorflow

# %%
# For Mac only
# %pip install tensorflow-macos
# %pip install tensorflow-metal

import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))

from keras import mixed_precision
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)

# %%
import os
import numpy as np
import keras
from keras import layers
from tensorflow import data as tf_data
import matplotlib.pyplot as plt

# %%
num_skipped = 0
for folder_name in ("Cat", "Dog"):
    folder_path = os.path.join("PetImages", folder_name)
    for fname in os.listdir(folder_path):
        fpath = os.path.join(folder_path, fname)
        try:
            fobj = open(fpath, "rb")
            is_jfif = b"JFIF" in fobj.peek(10)
        finally:
            fobj.close()

        if not is_jfif:
            num_skipped += 1
            # Delete corrupted image
            os.remove(fpath)

print(f"Deleted {num_skipped} images.")

# %%
image_size = (180, 180)
batch_size = 128

train_ds, val_ds = keras.utils.image_dataset_from_directory(
    "PetImages",
    validation_split=0.2,
    subset="both",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)

# %%
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.prefetch(tf.data.AUTOTUNE)

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(images[i]).astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
data_augmentation_layers = [
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
]


def data_augmentation(images):
    for layer in data_augmentation_layers:
        images = layer(images)
    return images

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(augmented_images[0]).astype("uint8"))
        plt.axis("off")

# %%
augmented_train_ds = train_ds.map(lambda x, y: (data_augmentation(x), y))

# %%
# Apply `data_augmentation` to the training images.
train_ds = train_ds.map(
    lambda img, label: (data_augmentation(img), label),
    num_parallel_calls=tf_data.AUTOTUNE,
)
# Prefetching samples in GPU memory helps maximize GPU utilization.
train_ds = train_ds.prefetch(tf_data.AUTOTUNE)
val_ds = val_ds.prefetch(tf_data.AUTOTUNE)

# %%
def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)

    # Entry block
    x = layers.Rescaling(1.0 / 255)(inputs)
    x = layers.Conv2D(128, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [256, 512, 728]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)
    if num_classes == 2:
        units = 1
    else:
        units = num_classes

    x = layers.Dropout(0.25)(x)
    # We specify activation=None so as to return logits
    outputs = layers.Dense(units, activation=None)(x)
    return keras.Model(inputs, outputs)


model = make_model(input_shape=image_size + (3,), num_classes=2)
keras.utils.plot_model(model, show_shapes=True)

# %%
epochs = 25

callbacks = [
    keras.callbacks.ModelCheckpoint("save_at_{epoch}.keras"),
]
model.compile(
    optimizer=keras.optimizers.Adam(0.0001),
    loss=keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=[keras.metrics.BinaryAccuracy(name="acc")],
)
model.fit(
    train_ds,
    epochs=epochs,
    callbacks=callbacks,
    validation_data=val_ds,
)

# %%
img = keras.utils.load_img("PetImages/Cat/6779.jpg", target_size=image_size)
plt.imshow(img)

img_array = keras.utils.img_to_array(img)
img_array = keras.ops.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = float(keras.ops.sigmoid(predictions[0][0]))
print(f"This image is {100 * (1 - score):.2f}% cat and {100 * score:.2f}% dog.")

# %% [markdown]
# ------------------------------------

# %% [markdown]
# ## Training CNN on Stanford Dogs Dataset

# %%
# %pip install tensorflow-datasets importlib_resources
# Out:
# Requirement already satisfied: tensorflow-datasets in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (4.9.9)
# Collecting importlib_resources
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: absl-py in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from tensorflow-datasets) (2.4.0)
# Requirement already satisfied: dm-tree in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from tensorflow-datasets) (0.1.9)
# Requirement already satisfied: etils>=1.9.1 in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (1.14.0)
# Requirement already satisfied: immutabledict in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from tensorflow-datasets) (4.3.1)
# Requirement already satisfied: numpy in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from tensorflow-datasets) (1.26.4)
# Requirement already satisfied: promise in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from tensorflow-datasets) (4.25.8)
# Requirement already satisfied: psutil in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from tensorflow-datasets) (7.0.0)
# Requirement already satisfied: pyarrow in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from tensorflow-datasets) (23.0.1)
# Requirement already satisfied: requests>=2.19.0 in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from tensorflow-datasets) (2.32.5)
# Requirement already satisfied: simple_parsing in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from tensorflow-datasets) (0.1.8)
# Requirement already satisfied: tensorflow-metadata in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from tensorflow-datasets) (1.17.3)
# Requirement already satisfied: termcolor in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from tensorflow-datasets) (3.3.0)
# Requirement already satisfied: toml in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: tqdm in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from tensorflow-datasets) (4.67.3)
# Requirement already satisfied: wrapt in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from tensorflow-datasets) (2.1.2)
# Requirement already satisfied: einops in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (0.8.2)
# Requirement already satisfied: fsspec in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (2026.2.0)
# Requirement already satisfied: typing_extensions in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (4.15.0)
# Requirement already satisfied: zipp in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from requests>=2.19.0->tensorflow-datasets) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from requests>=2.19.0->tensorflow-datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from requests>=2.19.0->tensorflow-datasets) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from requests>=2.19.0->tensorflow-datasets) (2026.2.25)
# Requirement already satisfied: attrs>=18.2.0 in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from dm-tree->tensorflow-datasets) (26.1.0)
# Requirement already satisfied: six in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from promise->tensorflow-datasets) (1.17.0)
# Requirement already satisfied: docstring-parser~=0.15 in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from simple_parsing->tensorflow-datasets) (0.17.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /opt/miniconda3/envs/DL-Project/lib/python3.11/site-packages (from tensorflow-metadata->tensorflow-datasets) (1.73.0)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Installing collected packages: importlib_resources
# Successfully installed importlib_resources-6.5.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##
